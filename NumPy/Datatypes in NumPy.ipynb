# %%
#Datatypes in NumPy
arr_int = np.array([1, 2, 3], dtype=np.int64)
arr_float = np.array([1.5, 2.5, 3.5], dtype=np.float32)

print(arr_int.dtype)  # Output: int64
print(arr_float.dtype)  # Output: float32
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Datatypes in NumPy
# ----> 2 arr_int = np.array([1, 2, 3], dtype=np.int64)
#       3 arr_float = np.array([1.5, 2.5, 3.5], dtype=np.float32)
#       5 print(arr_int.dtype)  # Output: int64
#
# NameError: name 'np' is not defined
