# %%
import numpy as np 
arr_2d = np.array([[1, 2, 3], [4, 5, 6]])
arr_3d = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])

print(arr_2d.shape)  # Output: (2, 3) (2D with 2 rows and 3 columns)
print(arr_3d.shape)  # Output: (2, 2, 2) (3D with 2 blocks, 2 rows, and 2 columns)
# Out:
# (2, 3)
# (2, 2, 2)
