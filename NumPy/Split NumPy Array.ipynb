# %%
#Split NumPy Array
import numpy as np
arr = np.array([1, 2, 3, 4, 5, 6])
print("Original array:", arr)
split_arr = np.split(arr, 3)  # Split into 3 equal parts
print("Split array:", split_arr)
# Out:
# Original array: [1 2 3 4 5 6]
# Split array: [array([1, 2]), array([3, 4]), array([5, 6])]

# %%
arr_3d = np.array([[[1, 2]], [[3, 4]], [[5, 6]]])
print("Original array:", arr)
split_arr_3d = np.split(arr_3d, 3)  # Splitting 3D array
print("Split Arrar 3d:",split_arr_3d)
# Out:
# Original array: [1 2 3 4 5 6]
# Split Arrar 3d: [array([[[1, 2]]]), array([[[3, 4]]]), array([[[5, 6]]])]
