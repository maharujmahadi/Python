# %%
import pandas as pd

# Creating a DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35]}
df = pd.DataFrame(data)

print("DataFrame created:\n",df)
# Out:
# DataFrame created:
#        Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
# Create another DataFrame
df2 = pd.DataFrame({'Name': ['David', 'Eva'], 'Age': [40, 45]})

# Concatenate the DataFrames
joined_df = pd.concat([df, df2], ignore_index=True)

# Display the result
print("Joined DataFrame:\n", joined_df)
# Out:
# Joined DataFrame:
#        Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40
# 4      Eva   45
