# %%
# Read an Excel file
import pandas as pd
df_excel = pd.read_excel('Pandas\compaction test.xlsx')  # Replace 'data.xlsx' with your Excel file path

# Display the DataFrame
print("\nDataFrame created:\n\n",df_excel.head(5))
# Out:
# DataFrame created:
#
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4        Unnamed: 5  \
# 0         NaN        NaN        NaN        NaN        NaN               NaN
# 1         NaN        no     water %     can no     can wt  can+ wet soil wt
# 2         NaN          1         10        NaN         10              29.2
# 3         NaN          2         10        NaN        9.4              28.6
# 4         NaN          3         12        NaN        9.9                45
#
#           Unnamed: 6   Unnamed: 7   Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0                NaN          NaN          NaN        NaN         NaN
# 1  can + dry soil wt  dry soil wt  moisture wt       MC %     avg MC%
# 2               27.7         17.7          1.5   8.474576    8.782743
# 3                 27         17.6          1.6   9.090909         NaN
# 4               41.5         31.6          3.5  11.075949    11.55172
#
#   Unnamed: 11               Unnamed: 12        Unnamed: 13  \
# 0         NaN                       NaN                NaN
# 1     mold wt  mold + compacted soil wt  compacted soil wt
# 2        4130                      5720               1590
# 3         NaN                       NaN                NaN
# 4        4130                      5810               1680
#
#            Unnamed: 14        Unnamed: 15
# 0                  NaN                NaN
# 1  wet density( gm/cc)  dry density KN/m2
# 2             1.684322          15.189173
# 3                  NaN                NaN
# 4             1.779661          15.650565
# <>:3: SyntaxWarning: invalid escape sequence '\c'
# <>:3: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\Maharuj\AppData\Local\Temp\ipykernel_5836\1932437251.py:3: SyntaxWarning: invalid escape sequence '\c'
#   df_excel = pd.read_excel('Pandas\compaction test.xlsx')  # Replace 'data.xlsx' with your Excel file path

# %%
#Read an Excel file
import pandas as pd
df_excel = pd.read_excel('Pandas\Student file.xlsx')  # Replace 'data.xlsx' with your Excel file path

# Display the DataFrame
print("\nDataFrame created:\n\n",df_excel.head(5))
# Out:
# DataFrame created:
#
#    Student Name  ID Number  CGPA     Department Semester
# 0        Alice    2023001   3.8  Computer Sci.      3rd
# 1          Bob    2023002   3.5     Mechanical      2nd
# 2      Charlie    2023003   3.9     Electrical      1st
# 3        David    2023004   3.6          Civil      4th
# 4          Eva    2023005   3.7          Civil      2nd
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\Maharuj\AppData\Local\Temp\ipykernel_5836\819437964.py:3: SyntaxWarning: invalid escape sequence '\S'
#   df_excel = pd.read_excel('Pandas\Student file.xlsx')  # Replace 'data.xlsx' with your Excel file path
