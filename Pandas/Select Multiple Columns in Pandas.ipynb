# %%
#Read an Excel file
import pandas as pd
df_excel = pd.read_excel('Pandas\Student file.xlsx')  # Replace 'data.xlsx' with your Excel file path

# Display the DataFrame
print("\nDataFrame created:\n\n",df_excel.head(5))
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\Maharuj\AppData\Local\Temp\ipykernel_13940\819437964.py:3: SyntaxWarning: invalid escape sequence '\S'
#   df_excel = pd.read_excel('Pandas\Student file.xlsx')  # Replace 'data.xlsx' with your Excel file path
# DataFrame created:
#
#        Name  ID Number  CGPA     Department Semester  Age
# 0    Alice    2023001   3.8  Computer Sci.      3rd   23
# 1      Bob    2023002   3.5     Mechanical      2nd   22
# 2  Charlie    2023003   3.9     Electrical      1st   21
# 3    David    2023004   3.6          Civil      4th   24
# 4      Eva    2023005   3.7          Civil      2nd   22

# %%
# # Select multiple columns
# import pandas as pd
# df_excel = pd.read_excel('Pandas\Student file.xlsx')  # Replace 'data.xlsx' with your Excel file path

# # Display the DataFrame
# print("\nDataFrame created:\n\n",df_excel.head(5))

selected_columns = df_excel [['CGPA', 'Age']]
# # Display the result
 print("Selected columns:\n",selected_columns)
# Out:
#   Cell In[11], line 10
#     print("Selected columns:\n",selected_columns)
#     ^
# IndentationError: unexpected indent
