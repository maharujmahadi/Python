# %%
#Read an Excel file
import pandas as pd
df_excel = pd.read_excel('E:\Higher Studies\BUET Poject\Ansary Sir\Python\Pandas\Student file.xlsx')  # Replace 'data.xlsx' with your Excel file path

# Display the DataFrame
print("\nDataFrame created:\n\n",df_excel.head())
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\H'
# <>:3: SyntaxWarning: invalid escape sequence '\H'
# C:\Users\Maharuj\AppData\Local\Temp\ipykernel_15648\4254029303.py:3: SyntaxWarning: invalid escape sequence '\H'
#   df_excel = pd.read_excel('E:\Higher Studies\BUET Poject\Ansary Sir\Python\Pandas\Student file.xlsx')  # Replace 'data.xlsx' with your Excel file path
# DataFrame created:
#
#        Name  ID Number  CGPA     Department Semester  Age
# 0    Alice    2023001   3.8  Computer Sci.      3rd   23
# 1      Bob    2023002   3.5     Mechanical      2nd   22
# 2  Charlie    2023003   3.9     Electrical      1st   21
# 3    David    2023004   3.6          Civil      4th   24
# 4      Eva    2023005   3.7          Civil      2nd   22

# %%
#Sorting in Pandas
# Sort by a single column
df_sorted = df_excel.sort_values(by='Age')
print("\nDataFrame sorted by Age:\n\n", df_sorted)

# Sort by multiple columns
#df_sorted_multi = df_excel.sort_values(by=['Age', 'Name'])
#print("\nDataFrame sorted by Age and Name:\n\n", df_sorted_multi)
# Out:
# DataFrame sorted by Age:
#
#        Name  ID Number  CGPA     Department Semester  Age
# 2  Charlie    2023003   3.9     Electrical      1st   21
# 1      Bob    2023002   3.5     Mechanical      2nd   22
# 4      Eva    2023005   3.7          Civil      2nd   22
# 8      Ian    2023009   4.0  Computer Sci.      4th   22
# 7    Helen    2023008   3.5     Electrical      2nd   23
# 0    Alice    2023001   3.8  Computer Sci.      3rd   23
# 5    Frank    2023006   3.4  Computer Sci.      3rd   24
# 3    David    2023004   3.6          Civil      4th   24
# 6    Grace    2023007   3.3     Mechanical      1st   25
# 9     Jack    2023010   3.2          Civil      3rd   25

# %%
#Sort by multiple columns
#Read an Excel file
import pandas as pd
df_excel = pd.read_excel(r'E:\\Higher Studies\\BUET Poject\\Ansary Sir\\Python\\Pandas\\Student file.xlsx')  # Replace 'data.xlsx' with your Excel file path

# Display the DataFrame
print("\nDataFrame created:\n\n",df_excel.head())

df_sorted_multi = df_excel.sort_values(by=['Age', 'Name'])
print("\nDataFrame sorted by Age and Name:\n\n", df_sorted_multi)
# Out:
# DataFrame created:
#
#        Name  ID Number  CGPA     Department Semester  Age
# 0    Alice    2023001   3.8  Computer Sci.      3rd   23
# 1      Bob    2023002   3.5     Mechanical      2nd   22
# 2  Charlie    2023003   3.9     Electrical      1st   21
# 3    David    2023004   3.6          Civil      4th   24
# 4      Eva    2023005   3.7          Civil      2nd   22
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15648\1409109806.py in ?()
#       5
#       6 # Display the DataFrame
#       7 print("\nDataFrame created:\n\n",df_excel.head())
#       8
# ----> 9 df_sorted_multi = df_excel.sort_values(by=['Age', 'Name'])
#      10 print("\nDataFrame sorted by Age and Name:\n\n", df_sorted_multi)
#
# ...
